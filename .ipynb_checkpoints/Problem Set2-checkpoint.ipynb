# %%
# Retrieve Airtable Records
import requests
import pandas as pd
headers = {
"Authorization": "Bearer key3UVZ0NwmLjgcUm", "Content-Type": "application/json; charset=utf-8"
}

params = (
('view', 'Grid view'),
)
# Using the Southwind Base stored in the COM5940 workspace in Firefox Airtable Account (bernard@intechnigence.com)
r = requests.get('https://api.airtable.com/v0/app79qmzvYkI0liqD/Posts?api_key=key3UVZ0NwmLjgcUm&sortField=postID&sortDirection=asc', headers=headers, params=params)
print("Status Code:",r.status_code)
dict = r.json()
dataset = []
postID = []
Title = []
result = []
for data in dict['records']:
     field_content = data['fields']
     dataset.append(field_content)
print(dataset)
print('\n')
print(pd.DataFrame(dataset))
print('\n')
for field in dataset:
    postID.append(field.get('postID'))
    Title.append(field.get('Title'))
    result.append(field.get('Body'))
print(result)
print(pd.DataFrame(result))
# Out:
# Status Code: 200
# ...

# %%
# Create Airtable Record
# AIRTABLE_BASE_ID='app79qmzvYkI0liqD'
# AIRTABLE_TABLE_NAME='Posts'
# AIRTABLE_API_KEY='api_key=key3UVZ0NwmLjgcUm'
# ENDPOINT='https://api.airtable.com/v0/app79qmzvYkI0liqD/Posts'


import requests
import pandas as pd
headers = {
"Authorization": "Bearer key3UVZ0NwmLjgcUm", "Content-Type": "application/json; charset=utf-8"
}

data = {
    "records":[
        {
        "fields": {
            "postID": "5",
            "Types": "123",
            "Title": "123",
            "Views": 16,
            "Author": "test",
            "Racename1": "《记仇杯》第一季",
            "Body": "<p>132</p>\n",
            "Comments": 1,
            "Post date": "2022-12-01"
            }
        }
    ]
}

params = (
('view', 'Grid view'),
)

r = requests.post('https://api.airtable.com/v0/app79qmzvYkI0liqD/Posts', headers=headers, json=data, params=params)
print("Status Code:",r.status_code)
print(r.json())

# Using the Southwind Base stored in the COM5940 workspace
r = requests.get('https://api.airtable.com/v0/app79qmzvYkI0liqD/Posts?api_key=key3UVZ0NwmLjgcUm&sortField=postID&sortDirection=asc', headers=headers, params=params)
print("Status Code:",r.status_code)
dict = r.json()
dataset = []
postID = []
Title = []
result = []
for data in dict['records']:
     field_content = data['fields']
     dataset.append(field_content)
print(dataset)
print('\n')
print(pd.DataFrame(dataset))
print('\n')
for field in dataset:
    postID.append(field.get('postID'))
    Title.append(field.get('Title'))
    result.append(field.get('Body'))
print(result)
print(pd.DataFrame(result))
# Out:
# Status Code: 200
# {'records': [{'id': 'rectUNj4QDqc0ybhG', 'createdTime': '2023-02-11T10:50:06.000Z', 'fields': {'postID': '5', 'Body': '<p>132</p>\n', 'Author': 'test', 'Post date': '2022-12-01', 'Views': 16, 'Comments': 1, 'Types': '123', 'Racename1': '《记仇杯》第一季', 'Title': '123', 'record_id': 'rectUNj4QDqc0ybhG'}}]}
# Status Code: 200
# ...

# %%
# Update Airtable Record
# AIRTABLE_BASE_ID='app79qmzvYkI0liqD'
# AIRTABLE_TABLE_NAME='Posts'
# AIRTABLE_API_KEY='api_key=key3UVZ0NwmLjgcUm'
# ENDPOINT='https://api.airtable.com/v0/app79qmzvYkI0liqD/Posts'


import requests
import pandas as pd
headers = {
"Authorization": "Bearer key3UVZ0NwmLjgcUm", "Content-Type": "application/json; charset=utf-8"
}

data = {
    "records":[
        {
        "id": "recL0el0EYZe2hBTi",
        "fields": {
            "postID": "5",
            "Types": "123",
            "Title": "123",
            "Views": 18,
            "Author": "test",
            "Racename1": "《记仇杯》第一季",
            "Body": "<p>132</p>\n",
            "Comments": 2,
            "Post date": "2022-12-01"
            }
        }
    ]
}

params = (
('view', 'Grid view'),
)

r = requests.put('https://api.airtable.com/v0/app79qmzvYkI0liqD/Posts', headers=headers, json=data, params=params)
print("Status Code:",r.status_code)
print(r.json())


r = requests.get('https://api.airtable.com/v0/app79qmzvYkI0liqD/Posts?api_key=key3UVZ0NwmLjgcUm&sortField=postID&sortDirection=asc', headers=headers, params=params)
print("Status Code:",r.status_code)
dict = r.json()
dataset = []
postID = []
Title = []
result = []
for data in dict['records']:
     field_content = data['fields']
     dataset.append(field_content)
print(dataset)
print('\n')
print(pd.DataFrame(dataset))
print('\n')
for field in dataset:
    postID.append(field.get('postID'))
    Title.append(field.get('Title'))
    result.append(field.get('Body'))
print(result)
print(pd.DataFrame(result))
# Out:
# Status Code: 200
# {'records': [{'id': 'recL0el0EYZe2hBTi', 'createdTime': '2023-02-04T11:24:37.000Z', 'fields': {'postID': '5', 'Types': '123', 'Title': '123', 'Views': 18, 'Author': 'test', 'Racename1': '《记仇杯》第一季', 'Body': '<p>132</p>\n', 'Comments': 2, 'Post date': '2022-12-01', 'record_id': 'recL0el0EYZe2hBTi'}}]}
# Status Code: 200
# ...

# %%
#
# Delete Record
#
import requests
import pandas as pd

headers = {'Authorization': 'Bearer key3UVZ0NwmLjgcUm', 'Content-Type': 'application/x-www-form-urlencoded'}

# data = {
#     "records":[
#         {
#         "id": "rectUNj4QDqc0ybhG",
#         "fields": {
#             "postID": "5",
#             "Types": "123",
#             "Title": "123",
#             "Views": 16,
#             "Author": "test",
#             "Racename1": "《记仇杯》第一季",
#             "Body": "<p>132</p>\n",
#             "Comments": 1,
#             "Post date": "2022-12-01"
#             }
#         }
#     ]
# }


r = requests.delete('https://api.airtable.com/v0/app79qmzvYkI0liqD/posts/rectUNj4QDqc0ybhG',headers=headers)
print("Status Code:",r.status_code)
print(r.json)

params = (
('view', 'Grid view'),
)

r = requests.get('https://api.airtable.com/v0/app79qmzvYkI0liqD/Posts?api_key=key3UVZ0NwmLjgcUm&sortField=postID&sortDirection=asc', headers=headers, params=params)
print("Status Code:",r.status_code)
dict = r.json()
dataset = []
postID = []
Title = []
result = []
for data in dict['records']:
     field_content = data['fields']
     dataset.append(field_content)
print(dataset)
print('\n')
print(pd.DataFrame(dataset))
print('\n')
for field in dataset:
    postID.append(field.get('postID'))
    Title.append(field.get('Title'))
    result.append(field.get('Body'))
print(result)
print(pd.DataFrame(result))
# Out:
# Status Code: 200
# <bound method Response.json of <Response [200]>>
# Status Code: 200
# [{'postID': '1', 'Types': '123', 'Title': '123', 'Views': 16, 'Author': 'test', 'Racename1': '《记仇杯》第一季', 'Body': '<p>132</p>\n', 'Comments': 1, 'Post date': '2022-12-01', 'record_id': 'recL0el0EYZe2hBTi'}, {'postID': '2', 'Types': '活动吐槽', 'Title': '仙麟杯预热', 'Views': 0, 'Author': 'test', 'Racename1': '《记仇杯》第一季', 'Body': '<p>看看甘雨</p>', 'Comments': 0, 'Post date': '2022-12-01', 'record_id': 'recwkarL2hNaBGS0N'}, {'postID': '3', 'Types': '555', 'Title': '555', 'Views': 0, 'Author': 'test', 'Racename1': '《记仇杯》第一季', 'Body': '<p>555</p>', 'Comments': 0, 'Post date': '2022-12-01', 'record_id': 'recTSmUT5pdYoGx1P'}]
#
#
#   postID Types  Title  Views Author Racename1          Body  Comments  \
# 0      1   123    123     16   test  《记仇杯》第一季  <p>132</p>\n         1
# 1      2  活动吐槽  仙麟杯预热      0   test  《记仇杯》第一季   <p>看看甘雨</p>         0
# 2      3   555    555      0   test  《记仇杯》第一季    <p>555</p>         0
# ...
